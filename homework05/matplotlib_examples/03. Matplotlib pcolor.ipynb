# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,1,5)
y = np.linspace(0,1,3)
X, Y = np.meshgrid(x, y)

# %%
x
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
y
# Out:
# array([0. , 0.5, 1. ])

# %%
X
# Out:
# array([[0.  , 0.25, 0.5 , 0.75, 1.  ],
#        [0.  , 0.25, 0.5 , 0.75, 1.  ],
#        [0.  , 0.25, 0.5 , 0.75, 1.  ]])

# %%
Y
# Out:
# array([[0. , 0. , 0. , 0. , 0. ],
#        [0.5, 0.5, 0.5, 0.5, 0.5],
#        [1. , 1. , 1. , 1. , 1. ]])

# %%
X.shape, Y.shape
# Out:
# ((3, 5), (3, 5))

# %%
mpl.cm.autumn.N
# Out:
# 256

# %%
mpl.cm.gray(np.arange(10), alpha=0.3)
# Out:
# array([[0.        , 0.        , 0.        , 0.3       ],
#        [0.00392157, 0.00392157, 0.00392157, 0.3       ],
#        [0.00784314, 0.00784314, 0.00784314, 0.3       ],
#        [0.01176471, 0.01176471, 0.01176471, 0.3       ],
#        [0.01568627, 0.01568627, 0.01568627, 0.3       ],
#        [0.01960784, 0.01960784, 0.01960784, 0.3       ],
#        [0.02352941, 0.02352941, 0.02352941, 0.3       ],
#        [0.02745098, 0.02745098, 0.02745098, 0.3       ],
#        [0.03137255, 0.03137255, 0.03137255, 0.3       ],
#        [0.03529412, 0.03529412, 0.03529412, 0.3       ]])

# %%
x = np.linspace(-10,10,150)
y = np.linspace(-10,10,150)
X,Y = np.meshgrid(x,y)

Z = np.cos(X) * np.cos(Y) * np.exp(-(X/5)**2-(Y/5)**2)

fig, ax = plt.subplots(figsize=(6,5))

norm = mpl.colors.Normalize(-abs(Z).max(), abs(Z).max())

p = ax.pcolor(X, Y, Z, norm = norm, cmap=mpl.cm.Paired)
ax.axis('tight')
ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(4))
ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(4))

cb = fig.colorbar(p, ax=ax)
cb.set_ticks([-1, -.5, 0, .5, 1])

# %%
fig, ax = plt.subplots(figsize=(6,5))
norm = mpl.colors.Normalize(-abs(Z).max(), abs(Z).max())
p = ax.contour(X, Y, Z, norm = norm, cmap=mpl.cm.bwr)
ax.axis('tight')
ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(4))
ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(4))

cb = fig.colorbar(p, ax=ax)
cb.set_ticks([-1, -.5, 0, .5, 1])

# %%
fig, ax = plt.subplots(figsize=(6,5))
p = ax.imshow(Z)

# %%
Z
# Out:
# array([[0.00023618, 0.0002832 , 0.00033166, ..., 0.00033166, 0.0002832 ,
#         0.00023618],
#        [0.0002832 , 0.00033958, 0.00039769, ..., 0.00039769, 0.00033958,
#         0.0002832 ],
#        [0.00033166, 0.00039769, 0.00046575, ..., 0.00046575, 0.00039769,
#         0.00033166],
#        ...,
#        [0.00033166, 0.00039769, 0.00046575, ..., 0.00046575, 0.00039769,
#         0.00033166],
#        [0.0002832 , 0.00033958, 0.00039769, ..., 0.00039769, 0.00033958,
#         0.0002832 ],
#        [0.00023618, 0.0002832 , 0.00033166, ..., 0.00033166, 0.0002832 ,
#         0.00023618]])

# %%
A = np.eye(10)
plt.imshow(A)

# %%
A = np.random.rand(10,20)
plt.imshow(A)
plt.colorbar()
